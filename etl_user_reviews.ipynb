# %%
import pandas as pd    # Para manejo de datos
import numpy as np    # Para operaciones matemáticas
import matplotlib.pyplot as plt     # Para gráficos
import seaborn as sns   # Para gráficos más bonitos
import os   # Para manejo de archivos
import datetime as dt   # Para manejo de fechas
import json   # Para manejo de archivos json
import ast    # Para manejo de archivos json
import re    # Para manejo de expresiones regulares

# %%
filas = list()

with open(r"C:\Users\baby_\Downloads\PI MLOps - STEAM-20231023T194033Z-001\PI MLOps - STEAM\user_reviews.json\australian_user_reviews.json", "r",encoding="utf-8") as archivo:
    for linea in archivo:
        filas.append(ast.literal_eval(linea))

# %%
df4 = pd.DataFrame(filas)
df4.head(5)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %%
df4.isnull().sum()
# Out:
# user_id     0
# user_url    0
# reviews     0
# dtype: int64

# %%
df4.shape
# Out:
# (25799, 3)

# %%
reviews = df4["reviews"]

# Imprimir la columna "reviews"
print(reviews.head(5))
# Out:
# 0    [{'funny': '', 'posted': 'Posted November 5, 2...
# 1    [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2    [{'funny': '', 'posted': 'Posted February 3.',...
# 3    [{'funny': '', 'posted': 'Posted October 14, 2...
# 4    [{'funny': '3 people found this review funny',...
# Name: reviews, dtype: object

# %%
df4_explotado = df4.explode('reviews').reset_index()

# Imprimir el DataFrame explotado
print(df4_explotado.head(5))
df4
# Out:
#    index            user_id  \
# 0      0  76561197970982479
# 1      0  76561197970982479
# 2      0  76561197970982479
# 3      1            js41637
# 4      1            js41637
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1  http://steamcommunity.com/profiles/76561197970...
# 2  http://steamcommunity.com/profiles/76561197970...
# 3               http://steamcommunity.com/id/js41637
# 4               http://steamcommunity.com/id/js41637
#
#                                              reviews
# 0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1  {'funny': '', 'posted': 'Posted July 15, 2011....
# 2  {'funny': '', 'posted': 'Posted April 21, 2011...
# 3  {'funny': '', 'posted': 'Posted June 24, 2014....
# 4  {'funny': '', 'posted': 'Posted September 8, 2...
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# 0      [{'funny': '', 'posted': 'Posted November 5, 2...
# 1      [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2      [{'funny': '', 'posted': 'Posted February 3.',...
# 3      [{'funny': '', 'posted': 'Posted October 14, 2...
# 4      [{'funny': '3 people found this review funny',...
# ...                                                  ...
# 25794  [{'funny': '', 'posted': 'Posted May 31.', 'la...
# 25795  [{'funny': '', 'posted': 'Posted June 17.', 'l...
# 25796  [{'funny': '1 person found this review funny',...
# 25797  [{'funny': '', 'posted': 'Posted July 21.', 'l...
# 25798  [{'funny': '1 person found this review funny',...
#
# [25799 rows x 3 columns]

# %%
df_user_reviews = pd.concat([df4_explotado.drop(['reviews'], axis=1), df4_explotado['reviews'].apply(pd.Series)], axis=1)

# %%
df_user_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59333 entries, 0 to 59332
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        59333 non-null  int64
#  1   user_id      59333 non-null  object
#  2   user_url     59333 non-null  object
#  3   funny        59305 non-null  object
#  4   posted       59305 non-null  object
#  5   last_edited  59305 non-null  object
#  6   item_id      59305 non-null  object
#  7   helpful      59305 non-null  object
#  8   recommend    59305 non-null  object
#  9   review       59305 non-null  object
#  10  0            0 non-null      float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 5.0+ MB

# %%
df_user_reviews
# Out:
#        index            user_id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59328  25797  76561198312638244
# 59329  25797  76561198312638244
# 59330  25798        LydiaMorley
# 59331  25798        LydiaMorley
# 59332  25798        LydiaMorley
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59328  http://steamcommunity.com/profiles/76561198312...
# 59329  http://steamcommunity.com/profiles/76561198312...
# 59330           http://steamcommunity.com/id/LydiaMorley
# 59331           http://steamcommunity.com/id/LydiaMorley
# 59332           http://steamcommunity.com/id/LydiaMorley
#
#                                   funny                     posted  \
# 0                                         Posted November 5, 2011.
# 1                                            Posted July 15, 2011.
# 2                                           Posted April 21, 2011.
# 3                                            Posted June 24, 2014.
# 4                                        Posted September 8, 2013.
# ...                                 ...                        ...
# 59328                                              Posted July 10.
# 59329                                               Posted July 8.
# 59330  1 person found this review funny             Posted July 3.
# 59331                                              Posted July 20.
# 59332                                               Posted July 2.
#
#       last_edited item_id                                          helpful  \
# 0                    1250                                   No ratings yet
# 1                   22200                                   No ratings yet
# 2                   43110                                   No ratings yet
# 3                  251610  15 of 20 people (75%) found this review helpful
# 4                  227300     0 of 1 people (0%) found this review helpful
# ...           ...     ...                                              ...
# 59328                  70                                   No ratings yet
# 59329              362890                                   No ratings yet
# 59330              273110    1 of 2 people (50%) found this review helpful
# 59331                 730                                   No ratings yet
# 59332                 440                                   No ratings yet
#
#       recommend                                             review   0
# 0          True  Simple yet with great replayability. In my opi... NaN
# 1          True               It's unique and worth a playthrough. NaN
# 2          True  Great atmosphere. The gunplay can be a bit chu... NaN
# 3          True  I know what you think when you see this title ... NaN
# 4          True  For a simple (it's actually not all that simpl... NaN
# ...         ...                                                ...  ..
# 59328      True  a must have classic from steam definitely wort... NaN
# 59329      True  this game is a perfect remake of the original ... NaN
# 59330      True  had so much fun plaing this and collecting res... NaN
# 59331      True                                                 :D NaN
# 59332      True                                     so much fun :D NaN
#
# [59333 rows x 11 columns]

# %%
df_user_reviews_retocado = df_user_reviews.drop(['funny', 'last_edited',0 ], axis=1)
df_user_reviews_retocado
# Out:
#        index            user_id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59328  25797  76561198312638244
# 59329  25797  76561198312638244
# 59330  25798        LydiaMorley
# 59331  25798        LydiaMorley
# 59332  25798        LydiaMorley
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59328  http://steamcommunity.com/profiles/76561198312...
# 59329  http://steamcommunity.com/profiles/76561198312...
# 59330           http://steamcommunity.com/id/LydiaMorley
# 59331           http://steamcommunity.com/id/LydiaMorley
# 59332           http://steamcommunity.com/id/LydiaMorley
#
#                           posted item_id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59330    1 of 2 people (50%) found this review helpful      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# 1                   It's unique and worth a playthrough.
# 2      Great atmosphere. The gunplay can be a bit chu...
# 3      I know what you think when you see this title ...
# 4      For a simple (it's actually not all that simpl...
# ...                                                  ...
# 59328  a must have classic from steam definitely wort...
# 59329  this game is a perfect remake of the original ...
# 59330  had so much fun plaing this and collecting res...
# 59331                                                 :D
# 59332                                     so much fun :D
#
# [59333 rows x 8 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Convertir la columna "review" a cadenas de texto
df_user_reviews_retocado['review'] = df_user_reviews_retocado['review'].astype(str)

# Crear una instancia del analizador de sentimientos de VaderSentiment
analyzer = SentimentIntensityAnalyzer()

# Crear una nueva columna "sentimiento"
df_user_reviews_retocado['Sentimiento'] = df_user_reviews_retocado['review'].apply(lambda x: analyzer.polarity_scores(x)['compound'])

# Imprimir el DataFrame con la nueva columna "sentimiento"
print(df_user_reviews_retocado.head(5))
# Out:
#    index            user_id  \
# 0      0  76561197970982479
# 1      0  76561197970982479
# 2      0  76561197970982479
# 3      1            js41637
# 4      1            js41637
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1  http://steamcommunity.com/profiles/76561197970...
# 2  http://steamcommunity.com/profiles/76561197970...
# 3               http://steamcommunity.com/id/js41637
# 4               http://steamcommunity.com/id/js41637
#
#                       posted item_id  \
# 0   Posted November 5, 2011.    1250
# 1      Posted July 15, 2011.   22200
# 2     Posted April 21, 2011.   43110
# 3      Posted June 24, 2014.  251610
# 4  Posted September 8, 2013.  227300
#
#                                            helpful recommend  \
# 0                                   No ratings yet      True
# 1                                   No ratings yet      True
# 2                                   No ratings yet      True
# 3  15 of 20 people (75%) found this review helpful      True
# 4     0 of 1 people (0%) found this review helpful      True
#
#                                               review  Sentimiento
# 0  Simple yet with great replayability. In my opi...       0.8481
# 1               It's unique and worth a playthrough.       0.2263
# 2  Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3  I know what you think when you see this title ...       0.9899
# 4  For a simple (it's actually not all that simpl...       0.9958

# %%
df_user_reviews_retocado
# Out:
#        index            user_id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59328  25797  76561198312638244
# 59329  25797  76561198312638244
# 59330  25798        LydiaMorley
# 59331  25798        LydiaMorley
# 59332  25798        LydiaMorley
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59328  http://steamcommunity.com/profiles/76561198312...
# 59329  http://steamcommunity.com/profiles/76561198312...
# 59330           http://steamcommunity.com/id/LydiaMorley
# 59331           http://steamcommunity.com/id/LydiaMorley
# 59332           http://steamcommunity.com/id/LydiaMorley
#
#                           posted item_id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59330    1 of 2 people (50%) found this review helpful      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   review  Sentimiento
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...       0.5574
# 59329  this game is a perfect remake of the original ...       0.9786
# 59330  had so much fun plaing this and collecting res...       0.7827
# 59331                                                 :D       0.5106
# 59332                                     so much fun :D       0.8349
#
# [59333 rows x 9 columns]

# %%
def etiquetar_sentimiento(texto):
    # Crear una instancia del analizador de sentimientos de VaderSentiment
    sia = SentimentIntensityAnalyzer()

    # Analizar el sentimiento del texto
    sentiment = sia.polarity_scores(texto)
    compound_score = sentiment['compound']

    # Asignar una etiqueta de sentimiento de acuerdo con el puntaje compuesto
    if pd.isnull(texto) or texto == '':
        return 1  # Return neutral if it is empty or NaN
    elif compound_score >= 0.05:
        return 2  # Buena puntuación
    elif compound_score <= -0.05:
        return 0  # Malas puntuaciones
    else:
        return 1  # Neutral puntuaciones

# %%
# Crear una nueva columna "etiqueta"
df_user_reviews_retocado['etiqueta'] = df_user_reviews_retocado['review'].apply(etiquetar_sentimiento)

# %%
df_user_reviews_retocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59333 entries, 0 to 59332
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        59333 non-null  int64
#  1   user_id      59333 non-null  object
#  2   user_url     59333 non-null  object
#  3   posted       59305 non-null  object
#  4   item_id      59305 non-null  object
#  5   helpful      59305 non-null  object
#  6   recommend    59305 non-null  object
#  7   review       59333 non-null  object
#  8   Sentimiento  59333 non-null  float64
#  9   etiqueta     59333 non-null  int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 4.5+ MB

# %%
# Contar el número de valores únicos en la columna "etiqueta"
num_etiquetas = df_user_reviews_retocado['etiqueta'].nunique()

# Imprimir el número de valores únicos
print("Hay", num_etiquetas, "valores únicos en la columna 'etiqueta'.")
# Out:
# Hay 3 valores únicos en la columna 'etiqueta'.

# %%
# Contar el número de veces que se repite cada valor en la columna "etiqueta"
conteo_etiquetas = df_user_reviews_retocado['Sentimiento'].value_counts()

# Imprimir el conteo de etiquetas
print(conteo_etiquetas)
# Out:
# Sentimiento
#  0.0000    10583
#  0.4404     1344
#  0.6369     1260
#  0.6249     1083
#  0.5106      631
#            ...
#  0.5356        1
#  0.4062        1
# -0.9313        1
# -0.4815        1
# -0.0591        1
# Name: count, Length: 7656, dtype: int64

# %%
df_user_reviews_retocado
# Out:
#        index            user_id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59328  25797  76561198312638244
# 59329  25797  76561198312638244
# 59330  25798        LydiaMorley
# 59331  25798        LydiaMorley
# 59332  25798        LydiaMorley
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59328  http://steamcommunity.com/profiles/76561198312...
# 59329  http://steamcommunity.com/profiles/76561198312...
# 59330           http://steamcommunity.com/id/LydiaMorley
# 59331           http://steamcommunity.com/id/LydiaMorley
# 59332           http://steamcommunity.com/id/LydiaMorley
#
#                           posted item_id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                helpful recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59330    1 of 2 people (50%) found this review helpful      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...       0.5574
# 59329  this game is a perfect remake of the original ...       0.9786
# 59330  had so much fun plaing this and collecting res...       0.7827
# 59331                                                 :D       0.5106
# 59332                                     so much fun :D       0.8349
#
#        etiqueta
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2
# ...         ...
# 59328         2
# 59329         2
# 59330         2
# 59331         2
# 59332         2
#
# [59333 rows x 10 columns]

# %%
df_user_reviews_retocado["año"].value_counts()
# Out:
# año
# 2014    22111
# 2015    18470
# 2013     6792
# 2012     1215
# 2011      532
# 2010       66
# Name: count, dtype: int64

# %%
# Convertir la primera letra de cada columna en mayúsculas
df_user_reviews_retocado.columns = df_user_reviews_retocado.columns.str.title()

# %%
df_user_reviews_retocado
# Out:
#        Index            User_Id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59328  25797  76561198312638244
# 59329  25797  76561198312638244
# 59330  25798        LydiaMorley
# 59331  25798        LydiaMorley
# 59332  25798        LydiaMorley
#
#                                                 User_Url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59328  http://steamcommunity.com/profiles/76561198312...
# 59329  http://steamcommunity.com/profiles/76561198312...
# 59330           http://steamcommunity.com/id/LydiaMorley
# 59331           http://steamcommunity.com/id/LydiaMorley
# 59332           http://steamcommunity.com/id/LydiaMorley
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                Helpful Recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59330    1 of 2 people (50%) found this review helpful      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   Review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...       0.5574
# 59329  this game is a perfect remake of the original ...       0.9786
# 59330  had so much fun plaing this and collecting res...       0.7827
# 59331                                                 :D       0.5106
# 59332                                     so much fun :D       0.8349
#
#        Etiqueta
# 0             2
# 1             2
# 2             2
# 3             2
# 4             2
# ...         ...
# 59328         2
# 59329         2
# 59330         2
# 59331         2
# 59332         2
#
# [59333 rows x 10 columns]

# %%
# Contar el número de valores nulos en la columna "Posted"
num_nulos = df_user_reviews_retocado['Posted'].isnull().sum()

# Imprimir el número de valores nulos
print("Hay", num_nulos, "valores nulos en la columna 'Posted'.")
# Out:
# Hay 0 valores nulos en la columna 'Posted'.

# %%
# Reemplazar los valores nulos o NaN en la columna "Posted" por un valor predeterminado
df_user_reviews_retocado['Posted'] = df_user_reviews_retocado['Posted'].fillna('')

# Encontrar las filas que contienen el valor 20 en la columna "Posted"
filas_20 = df_user_reviews_retocado.query("Posted.str.contains('20')", engine='python')

# Imprimir las filas que contienen el valor 20 en la columna "Posted"
print(filas_20)
# Out:
#        Index            User_Id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59293  25769        72947282842
# 59295  25771          ApxLGhost
# 59304  25780  76561198267374962
# 59322  25793     JustMielThings
# 59331  25798        LydiaMorley
#
#                                                 User_Url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59293           http://steamcommunity.com/id/72947282842
# 59295             http://steamcommunity.com/id/ApxLGhost
# 59304  http://steamcommunity.com/profiles/76561198267...
# 59322        http://steamcommunity.com/id/JustMielThings
# 59331           http://steamcommunity.com/id/LydiaMorley
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59293   Posted October 31, 2015.     730
# 59295  Posted December 14, 2015.     730
# 59304  Posted December 29, 2015.  369200
# 59322             Posted May 20.     570
# 59331            Posted July 20.     730
#
#                                                Helpful Recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59293                                   No ratings yet      True
# 59295                                   No ratings yet      True
# 59304    1 of 2 people (50%) found this review helpful      True
# 59322                                   No ratings yet      True
# 59331                                   No ratings yet      True
#
#                                                   Review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59293                                   Prettyy Mad Game      -0.4939
# 59295                                 AMAZING GAME 10/10       0.6739
# 59304  Why I voted yes? 1. Girl characters have boobs...       0.7089
# 59322                                           Good one       0.4404
# 59331                                                 :D       0.5106
#
#        Etiqueta   año
# 0             2  2011
# 1             2  2011
# 2             2  2011
# 3             2  2014
# 4             2  2013
# ...         ...   ...
# 59293         0  2015
# 59295         2  2015
# 59304         2  2015
# 59322         2   NaN
# 59331         2   NaN
#
# [49494 rows x 11 columns]

# %%
# Contar el número de valores nulos en la columna "Posted"
num_nulos = df_user_reviews_retocado['Posted'].isnull().sum()

# Imprimir el número de valores nulos
print("Hay", num_nulos, "valores nulos en la columna 'Posted'.")
# Out:
# Hay 0 valores nulos en la columna 'Posted'.

# %%
# Encontrar las filas que contienen el valor 20 en la columna "Posted"
filas_20 = df_user_reviews_retocado.query("Posted.str.contains('20')", engine='python')

# Imprimir las filas que contienen el valor 20 en la columna "Posted"
filas_20
# Out:
#        Index            User_Id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59293  25769        72947282842
# 59295  25771          ApxLGhost
# 59304  25780  76561198267374962
# 59322  25793     JustMielThings
# 59331  25798        LydiaMorley
#
#                                                 User_Url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59293           http://steamcommunity.com/id/72947282842
# 59295             http://steamcommunity.com/id/ApxLGhost
# 59304  http://steamcommunity.com/profiles/76561198267...
# 59322        http://steamcommunity.com/id/JustMielThings
# 59331           http://steamcommunity.com/id/LydiaMorley
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59293   Posted October 31, 2015.     730
# 59295  Posted December 14, 2015.     730
# 59304  Posted December 29, 2015.  369200
# 59322             Posted May 20.     570
# 59331            Posted July 20.     730
#
#                                                Helpful Recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59293                                   No ratings yet      True
# 59295                                   No ratings yet      True
# 59304    1 of 2 people (50%) found this review helpful      True
# 59322                                   No ratings yet      True
# 59331                                   No ratings yet      True
#
#                                                   Review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59293                                   Prettyy Mad Game      -0.4939
# 59295                                 AMAZING GAME 10/10       0.6739
# 59304  Why I voted yes? 1. Girl characters have boobs...       0.7089
# 59322                                           Good one       0.4404
# 59331                                                 :D       0.5106
#
#        Etiqueta   año
# 0             2  2011
# 1             2  2011
# 2             2  2011
# 3             2  2014
# 4             2  2013
# ...         ...   ...
# 59293         0  2015
# 59295         2  2015
# 59304         2  2015
# 59322         2   NaN
# 59331         2   NaN
#
# [49494 rows x 11 columns]

# %%
import re

# Definir la variable pattern
pattern = r'\d{4}'

def contiene_4_numeros(fila):
    matches = re.findall(pattern, str(fila))
    return len(matches) == 1

# Aplicar la función a cada fila del DataFrame
filas_con_4_numeros = df_user_reviews_retocado[df_user_reviews_retocado['Posted'].apply(lambda x: contiene_4_numeros(x))]

filas_con_4_numeros
# Out:
#        Index            User_Id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59280  25764            wayfeng
# 59283  25765  76561198251004808
# 59293  25769        72947282842
# 59295  25771          ApxLGhost
# 59304  25780  76561198267374962
#
#                                                 User_Url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59280               http://steamcommunity.com/id/wayfeng
# 59283  http://steamcommunity.com/profiles/76561198251...
# 59293           http://steamcommunity.com/id/72947282842
# 59295             http://steamcommunity.com/id/ApxLGhost
# 59304  http://steamcommunity.com/profiles/76561198267...
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59280   Posted October 14, 2015.     730
# 59283   Posted October 10, 2015.  253980
# 59293   Posted October 31, 2015.     730
# 59295  Posted December 14, 2015.     730
# 59304  Posted December 29, 2015.  369200
#
#                                                Helpful Recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59280   1 of 1 people (100%) found this review helpful      True
# 59283                                   No ratings yet      True
# 59293                                   No ratings yet      True
# 59295                                   No ratings yet      True
# 59304    1 of 2 people (50%) found this review helpful      True
#
#                                                   Review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59280                                     its FUNNNNNNNN       0.0000
# 59283  Awesome fantasy game if you don't mind the gra...       0.7650
# 59293                                   Prettyy Mad Game      -0.4939
# 59295                                 AMAZING GAME 10/10       0.6739
# 59304  Why I voted yes? 1. Girl characters have boobs...       0.7089
#
#        Etiqueta   año
# 0             2  2011
# 1             2  2011
# 2             2  2011
# 3             2  2014
# 4             2  2013
# ...         ...   ...
# 59280         1  2015
# 59283         2  2015
# 59293         0  2015
# 59295         2  2015
# 59304         2  2015
#
# [49186 rows x 11 columns]

# %%
df_user_reviews_retocado['año'] = df_user_reviews_retocado['Posted'].str.extract(r'(\d{4})')

# %%
df_user_reviews_retocado["año"].value_counts()
# Out:
# año
# 2014    22111
# 2015    18470
# 2013     6792
# 2012     1215
# 2011      532
# 2010       66
# Name: count, dtype: int64

# %%
df_user_reviews_retocado
# Out:
#        Index            User_Id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59328  25797  76561198312638244
# 59329  25797  76561198312638244
# 59330  25798        LydiaMorley
# 59331  25798        LydiaMorley
# 59332  25798        LydiaMorley
#
#                                                 User_Url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59328  http://steamcommunity.com/profiles/76561198312...
# 59329  http://steamcommunity.com/profiles/76561198312...
# 59330           http://steamcommunity.com/id/LydiaMorley
# 59331           http://steamcommunity.com/id/LydiaMorley
# 59332           http://steamcommunity.com/id/LydiaMorley
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                Helpful Recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59330    1 of 2 people (50%) found this review helpful      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   Review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...       0.5574
# 59329  this game is a perfect remake of the original ...       0.9786
# 59330  had so much fun plaing this and collecting res...       0.7827
# 59331                                                 :D       0.5106
# 59332                                     so much fun :D       0.8349
#
#        Etiqueta   año
# 0             2  2011
# 1             2  2011
# 2             2  2011
# 3             2  2014
# 4             2  2013
# ...         ...   ...
# 59328         2   NaN
# 59329         2   NaN
# 59330         2   NaN
# 59331         2   NaN
# 59332         2   NaN
#
# [59333 rows x 11 columns]

# %%
pd.set_option('display.max_colwidth', None)

# %%
# Eliminar la columna "Index" del DataFrame
df_user_reviews_retocado = df_user_reviews_retocado.drop("Index", axis=1)

# %%
df_user_reviews_retocado
# Out:
#                  User_Id                                           User_Url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                Helpful Recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59330    1 of 2 people (50%) found this review helpful      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   Review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...       0.5574
# 59329  this game is a perfect remake of the original ...       0.9786
# 59330  had so much fun plaing this and collecting res...       0.7827
# 59331                                                 :D       0.5106
# 59332                                     so much fun :D       0.8349
#
#        Etiqueta   año
# 0             2  2011
# 1             2  2011
# 2             2  2011
# 3             2  2014
# 4             2  2013
# ...         ...   ...
# 59328         2   NaN
# 59329         2   NaN
# 59330         2   NaN
# 59331         2   NaN
# 59332         2   NaN
#
# [59333 rows x 10 columns]

# %%
df_user_reviews_retocado = df_user_reviews_retocado.rename(columns={'Etiqueta': 'Sentiment Analysis'})

# %%
df_user_reviews_retocado
# Out:
#                  User_Id                                           User_Url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                Helpful Recommend  \
# 0                                       No ratings yet      True
# 1                                       No ratings yet      True
# 2                                       No ratings yet      True
# 3      15 of 20 people (75%) found this review helpful      True
# 4         0 of 1 people (0%) found this review helpful      True
# ...                                                ...       ...
# 59328                                   No ratings yet      True
# 59329                                   No ratings yet      True
# 59330    1 of 2 people (50%) found this review helpful      True
# 59331                                   No ratings yet      True
# 59332                                   No ratings yet      True
#
#                                                   Review  Sentimiento  \
# 0      Simple yet with great replayability. In my opi...       0.8481
# 1                   It's unique and worth a playthrough.       0.2263
# 2      Great atmosphere. The gunplay can be a bit chu...       0.9117
# 3      I know what you think when you see this title ...       0.9899
# 4      For a simple (it's actually not all that simpl...       0.9958
# ...                                                  ...          ...
# 59328  a must have classic from steam definitely wort...       0.5574
# 59329  this game is a perfect remake of the original ...       0.9786
# 59330  had so much fun plaing this and collecting res...       0.7827
# 59331                                                 :D       0.5106
# 59332                                     so much fun :D       0.8349
#
#        Sentiment Analysis   año
# 0                       2  2011
# 1                       2  2011
# 2                       2  2011
# 3                       2  2014
# 4                       2  2013
# ...                   ...   ...
# 59328                   2   NaN
# 59329                   2   NaN
# 59330                   2   NaN
# 59331                   2   NaN
# 59332                   2   NaN
#
# [59333 rows x 10 columns]

# %%
df_user_reviews_retocado = df_user_reviews_retocado.drop(columns=['Review'])

# %%
df_user_reviews_retocado
# Out:
#                  User_Id                                           User_Url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3                js41637               http://steamcommunity.com/id/js41637
# 4                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 59328  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59329  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 59330        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59331        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 59332        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                           Posted Item_Id  \
# 0       Posted November 5, 2011.    1250
# 1          Posted July 15, 2011.   22200
# 2         Posted April 21, 2011.   43110
# 3          Posted June 24, 2014.  251610
# 4      Posted September 8, 2013.  227300
# ...                          ...     ...
# 59328            Posted July 10.      70
# 59329             Posted July 8.  362890
# 59330             Posted July 3.  273110
# 59331            Posted July 20.     730
# 59332             Posted July 2.     440
#
#                                                Helpful Recommend  Sentimiento  \
# 0                                       No ratings yet      True       0.8481
# 1                                       No ratings yet      True       0.2263
# 2                                       No ratings yet      True       0.9117
# 3      15 of 20 people (75%) found this review helpful      True       0.9899
# 4         0 of 1 people (0%) found this review helpful      True       0.9958
# ...                                                ...       ...          ...
# 59328                                   No ratings yet      True       0.5574
# 59329                                   No ratings yet      True       0.9786
# 59330    1 of 2 people (50%) found this review helpful      True       0.7827
# 59331                                   No ratings yet      True       0.5106
# 59332                                   No ratings yet      True       0.8349
#
#        Sentiment Analysis   año
# 0                       2  2011
# 1                       2  2011
# 2                       2  2011
# 3                       2  2014
# 4                       2  2013
# ...                   ...   ...
# 59328                   2   NaN
# 59329                   2   NaN
# 59330                   2   NaN
# 59331                   2   NaN
# 59332                   2   NaN
#
# [59333 rows x 9 columns]

# %%
df_user_reviews_retocado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59333 entries, 0 to 59332
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   User_Id             59333 non-null  object
#  1   User_Url            59333 non-null  object
#  2   Posted              59333 non-null  object
#  3   Item_Id             59305 non-null  object
#  4   Helpful             59305 non-null  object
#  5   Recommend           59305 non-null  object
#  6   Sentimiento         59333 non-null  float64
#  7   Sentiment Analysis  59333 non-null  int64
#  8   año                 49186 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 4.1+ MB

# %%
df_user_reviews_retocado = df_user_reviews_retocado.drop(columns=['User_Url','Helpful'])

# %%
df_user_reviews_retocado
# Out:
#                  User_Id                     Posted Item_Id Recommend  \
# 0      76561197970982479   Posted November 5, 2011.    1250      True
# 1      76561197970982479      Posted July 15, 2011.   22200      True
# 2      76561197970982479     Posted April 21, 2011.   43110      True
# 3                js41637      Posted June 24, 2014.  251610      True
# 4                js41637  Posted September 8, 2013.  227300      True
# ...                  ...                        ...     ...       ...
# 59328  76561198312638244            Posted July 10.      70      True
# 59329  76561198312638244             Posted July 8.  362890      True
# 59330        LydiaMorley             Posted July 3.  273110      True
# 59331        LydiaMorley            Posted July 20.     730      True
# 59332        LydiaMorley             Posted July 2.     440      True
#
#        Sentimiento  Sentiment Analysis   año
# 0           0.8481                   2  2011
# 1           0.2263                   2  2011
# 2           0.9117                   2  2011
# 3           0.9899                   2  2014
# 4           0.9958                   2  2013
# ...            ...                 ...   ...
# 59328       0.5574                   2   NaN
# 59329       0.9786                   2   NaN
# 59330       0.7827                   2   NaN
# 59331       0.5106                   2   NaN
# 59332       0.8349                   2   NaN
#
# [59333 rows x 7 columns]

# %%
df_user_reviews_retocado = df_user_reviews_retocado.dropna(subset=['año'])
df_user_reviews_retocado.isnull().sum()
# Out:
# User_Id               0
# Posted                0
# Item_Id               0
# Recommend             0
# Sentimiento           0
# Sentiment Analysis    0
# año                   0
# dtype: int64

# %%
df_user_reviews_retocado
# Out:
#                  User_Id                     Posted Item_Id Recommend  \
# 0      76561197970982479   Posted November 5, 2011.    1250      True
# 1      76561197970982479      Posted July 15, 2011.   22200      True
# 2      76561197970982479     Posted April 21, 2011.   43110      True
# 3                js41637      Posted June 24, 2014.  251610      True
# 4                js41637  Posted September 8, 2013.  227300      True
# ...                  ...                        ...     ...       ...
# 59280            wayfeng   Posted October 14, 2015.     730      True
# 59283  76561198251004808   Posted October 10, 2015.  253980      True
# 59293        72947282842   Posted October 31, 2015.     730      True
# 59295          ApxLGhost  Posted December 14, 2015.     730      True
# 59304  76561198267374962  Posted December 29, 2015.  369200      True
#
#        Sentimiento  Sentiment Analysis   año
# 0           0.8481                   2  2011
# 1           0.2263                   2  2011
# 2           0.9117                   2  2011
# 3           0.9899                   2  2014
# 4           0.9958                   2  2013
# ...            ...                 ...   ...
# 59280       0.0000                   1  2015
# 59283       0.7650                   2  2015
# 59293      -0.4939                   0  2015
# 59295       0.6739                   2  2015
# 59304       0.7089                   2  2015
#
# [49186 rows x 7 columns]

# %%
df_user_reviews_retocado = df_user_reviews_retocado.drop(columns=['Posted','Sentimiento'])

# %%
df_user_reviews_retocado.to_csv('User_reviews.csv', index=False)

# %%
df_user_reviews_retocado.to_parquet("User_reviews.parquet")

# %%
df23 = pd.read_parquet("User_reviews.parquet")
df23
# Out:
#                  User_Id Item_Id  Recommend  Sentiment Analysis   año
# 0      76561197970982479    1250       True                   2  2011
# 1      76561197970982479   22200       True                   2  2011
# 2      76561197970982479   43110       True                   2  2011
# 3                js41637  251610       True                   2  2014
# 4                js41637  227300       True                   2  2013
# ...                  ...     ...        ...                 ...   ...
# 59280            wayfeng     730       True                   1  2015
# 59283  76561198251004808  253980       True                   2  2015
# 59293        72947282842     730       True                   0  2015
# 59295          ApxLGhost     730       True                   2  2015
# 59304  76561198267374962  369200       True                   2  2015
#
# [49186 rows x 5 columns]

# %%
df12 = pd.read_csv("User_reviews.csv")

# Escribir el DataFrame en un archivo Parquet
df12.to_parquet("User_revuews.parquet")
